# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
import random
import gym
import numpy as np
from collections import deque
import torch
import torch.nn as nn
import torch.optim as optim
import pygame
from math import pi, sin, cos, sqrt
from random import randrange
from gym import spaces
from pygame.locals import *
import matplotlib.pyplot as plt
import pylab


class droneEnv(gym.Env):
    def __init__(self, render_every_frame, mouse_target):
        super(droneEnv, self).__init__()

        self.render_every_frame = render_every_frame
        # Makes the target follow the mouse
        self.mouse_target = mouse_target

        # Initialize Pygame, load sprites
        pygame.init()
        self.screen = pygame.display.set_mode((800, 800))
        self.FramePerSec = pygame.time.Clock()

        self.player = pygame.image.load(os.path.join("/home/cbeario/DeepPrior/Flight_UAV/background/drone_old.png"))
        self.player.convert()

        self.target = pygame.image.load(os.path.join("/home/cbeario/DeepPrior/Flight_UAV/background/target_old.png"))
        self.target.convert()

        pygame.font.init()
        self.myfont = pygame.font.SysFont("Comic Sans MS", 20)

        # Physics constants
        self.FPS = 60
        self.gravity = 0.08
        self.thruster_amplitude = 0.04
        self.diff_amplitude = 0.0006
        self.thruster_mean = 0.04
        self.mass = 1
        self.arm = 25
        self.target_counter = 0

        # Initialize variables
        (self.a, self.ad, self.add) = (0, 0, 0)
        (self.x, self.xd, self.xdd) = (400, 0, 0)
        (self.y, self.yd, self.ydd) = (400, 0, 0)
        self.xt = randrange(200, 600)
        self.yt = randrange(200, 600)

        # Initialize game variables
        #self.target_counter = 0
        self.reward = 0
        self.time = 0
        self.time_limit = 20
        if self.mouse_target is True:
            self.time_limit = 1000

        # 5 actions: Nothing, Up, Down, Right, Left
        self.action_space = gym.spaces.Discrete(5)
        # 8 observations: angle_to_up, velocity, angle_velocity, distance_to_target, angle_to_target, angle_target_and_velocity, distance_to_target
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(7,))

    def reset(self):
        # Reset variables
        (self.a, self.ad, self.add) = (0, 0, 0)
        (self.x, self.xd, self.xdd) = (400, 0, 0)
        (self.y, self.yd, self.ydd) = (400, 0, 0)
        self.xt = randrange(200, 600)
        self.yt = randrange(200, 600)

        #self.target_counter = 0
        self.reward = 0
        self.time = 0

        return self.get_obs()

    def get_obs(self) -> np.ndarray:

        angle_to_up = self.a / 180 * pi
        velocity = sqrt(self.xd**2 + self.yd**2)
        angle_velocity = self.ad
        distance_to_target = (
            sqrt((self.xt - self.x) ** 2 + (self.yt - self.y) ** 2) / 500
        )
        angle_to_target = np.arctan2(self.yt - self.y, self.xt - self.x)
        # Angle between the to_target vector and the velocity vector
        angle_target_and_velocity = np.arctan2(
            self.yt - self.y, self.xt - self.x
        ) - np.arctan2(self.yd, self.xd)
        distance_to_target = (
            sqrt((self.xt - self.x) ** 2 + (self.yt - self.y) ** 2) / 500
        )
        return np.array(
            [
                angle_to_up,
                velocity,
                angle_velocity,
                distance_to_target,
                angle_to_target,
                angle_target_and_velocity,
                distance_to_target,
            ]
        ).astype(np.float32)

    def step(self, action):
        # Game loop
        self.reward = 0.0
        action = int(action)

        # Act every 5 frames
        for _ in range(5):
            self.time += 1 / 60

            if self.mouse_target is True:
                self.xt, self.yt = pygame.mouse.get_pos()

            # Initialize accelerations
            self.xdd = 0
            self.ydd = self.gravity
            self.add = 0
            thruster_left = self.thruster_mean
            thruster_right = self.thruster_mean

            if action == 0:
                pass
            elif action == 1:
                thruster_left += self.thruster_amplitude
                thruster_right += self.thruster_amplitude
            elif action == 2:
                thruster_left -= self.thruster_amplitude
                thruster_right -= self.thruster_amplitude
            elif action == 3:
                thruster_left += self.diff_amplitude
                thruster_right -= self.diff_amplitude
            elif action == 4:
                thruster_left -= self.diff_amplitude
                thruster_right += self.diff_amplitude

            # Calculating accelerations with Newton's laws of motions
            self.xdd += (
                -(thruster_left + thruster_right) * sin(self.a * pi / 180) / self.mass
            )
            self.ydd += (
                -(thruster_left + thruster_right) * cos(self.a * pi / 180) / self.mass
            )
            self.add += self.arm * (thruster_right - thruster_left) / self.mass

            self.xd += self.xdd
            self.yd += self.ydd
            self.ad += self.add
            self.x += self.xd
            self.y += self.yd
            self.a += self.ad

            dist = sqrt((self.x - self.xt) ** 2 + (self.y - self.yt) ** 2)

            # Reward per step survived
            self.reward += 1 / 60
            # Penalty according to the distance to target
            self.reward -= dist / (100 * 60)

            if dist < 50:
                # Reward if close to target
                self.xt = randrange(200, 600)
                self.yt = randrange(200, 600)
                self.reward += 100
                self.target_counter+=1

            # If out of time
            if self.time > self.time_limit:
                done = True
                break

            # If too far from target (crash)
            elif dist > 1000:
                self.reward -= 1000
                done = True
                break

            else:
                done = False

            if self.render_every_frame is True:
                self.render("yes")

        info = {}

        return (
            self.get_obs(),
            self.reward,
            done,
            info,
        )

    def render(self, mode):
        # Pygame rendering
        pygame.event.get()
        self.screen.fill(0)
        self.screen.blit(
            self.target,
            (
                self.xt - int(self.target.get_width() / 2),
                self.yt - int(self.target.get_height() / 2),
            ),
        )
        player_copy = pygame.transform.rotate(self.player, self.a)
        self.screen.blit(
            player_copy,
            (
                self.x - int(player_copy.get_width() / 2),
                self.y - int(player_copy.get_height() / 2),
            ),
        )

        textsurface = self.myfont.render(
            "Collected: " + str(self.target_counter), False, (255, 255, 255)
        )
        self.screen.blit(textsurface, (20, 20))
        textsurface3 = self.myfont.render(
            "Time: " + str(int(self.time)), False, (255, 255, 255)
        )
        self.screen.blit(textsurface3, (20, 50))

        pygame.display.update()
        self.FramePerSec.tick(self.FPS)

    def close(self):
        pygame.quit()


class Net(nn.Module):
    def __init__(self, input_size, output_size):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(input_size, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 64)
        self.fc4 = nn.Linear(64, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = self.fc4(x)
        return x

class DQNAgent:
    def __init__(self, env):
        self.env = env
        self.state_size = self.env.observation_space.shape[0]
        self.action_size = self.env.action_space.n
        self.EPISODES = 300
        self.memory = deque(maxlen=2000)

        self.gamma = 0.5  # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.001
        self.epsilon_decay = 0.999
        self.batch_size = 64
        self.train_start = 1000
        self.max_episode_steps=1000
        self.scores, self.episodes, self.average = [], [], []
        # create main model
        self.model = Net(self.state_size, self.action_size)
        self.optimizer = optim.RMSprop(self.model.parameters(), lr=0.00025)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        if len(self.memory) > self.train_start:
            if self.epsilon > self.epsilon_min:
                self.epsilon *= self.epsilon_decay

    def act(self, state):
        state = torch.FloatTensor(state).unsqueeze(0)
        if np.random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            with torch.no_grad():
                action_values = self.model(state)
                return action_values[0].argmax(dim=1).item()  # Ensure action_values has the correct dimension

    def PlotModel(self, score, episode):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores) / len(self.scores))
        pylab.plot(self.episodes, self.average, 'r')
        pylab.plot(self.episodes, self.scores, 'b')
        pylab.ylabel('Score', fontsize=18)
        pylab.xlabel('Steps', fontsize=18)
        dqn = 'DQN_'
        softupdate = ''
        try:
            pylab.savefig("DNARL_Drone_1.png")
        except OSError:
            pass

        return str(self.average[-1])[:5]


    def replay(self):
        if len(self.memory) < self.train_start:
            return
        minibatch = random.sample(self.memory, min(len(self.memory), self.batch_size))

        states = torch.zeros((len(minibatch), self.state_size))
        next_states = torch.zeros((len(minibatch), self.state_size))
        actions = torch.zeros(len(minibatch), dtype=torch.long)
        rewards = torch.zeros(len(minibatch))
        dones = torch.zeros(len(minibatch), dtype=torch.bool)

        for idx, (state, action, reward, next_state, done) in enumerate(minibatch):
            states[idx] = torch.FloatTensor(state)
            next_states[idx] = torch.FloatTensor(next_state)
            actions[idx] = action
            rewards[idx] = reward
            dones[idx] = done

        current_q_values = self.model(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        next_q_values = self.model(next_states).max(1)[0]
        expected_q_values = rewards + self.gamma * next_q_values * (~dones)

        loss = nn.functional.mse_loss(current_q_values, expected_q_values.detach())

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
   

    def train(self):
        for e in range(self.EPISODES):
            state = self.env.reset()
            state = np.reshape(state, [1, self.state_size])
            done = False
            i = 0
            while not done:
                self.env.render('human')
                action = self.act(state)
                next_state, reward, done, _ = self.env.step(action)
                next_state = np.reshape(next_state, [1, self.state_size])
                if not done or i == self.max_episode_steps - 1:
                    reward = reward
                else:
                    reward = -100
                self.remember(state, action, reward, next_state, done)
                state = next_state
                i += 1
                if done:
                    average = self.PlotModel(i, e)
                    print(f"episode: {e}/{self.EPISODES}, score: {i}, e: {self.epsilon:.2}, average: {average}")
                    if i == self.EPISODES-1:
                        print("Saving trained model as drone-dqn.pt")
                        torch.save(self.model.state_dict(), "drone-dqn.pt")
                self.replay()

    def test(self, model_path):
        self.model.load_state_dict(torch.load(model_path))
        self.model.eval()
        for e in range(self.EPISODES):
            state = self.env.reset()
            state = np.reshape(state, [1, self.state_size])
            done = False
            i = 0
            while not done:
                self.env.render('human')
                with torch.no_grad():
                    action = self.model(torch.FloatTensor(state)).max(1)[1].view(1, 1).item()
                next_state, reward, done, _ = self.env.step(action)
                next_state = np.reshape(next_state, [1, self.state_size])
                state = next_state
                i += 1
                if done:
                    print(f"episode: {e}/{self.EPISODES}, score: {i}")

    def save(self, name):
        torch.save(self.model.state_dict(), name)

# %%
env = droneEnv(False,False)
agent = DQNAgent(env)

# %%
agent.train()
# Out:
# episode: 0/300, score: 53, e: 1.0, average: 53.0
# episode: 1/300, score: 68, e: 1.0, average: 60.5
# episode: 2/300, score: 54, e: 1.0, average: 58.33
# episode: 3/300, score: 74, e: 1.0, average: 62.25
# episode: 4/300, score: 48, e: 1.0, average: 59.4
# episode: 5/300, score: 63, e: 1.0, average: 60.0
# episode: 6/300, score: 49, e: 1.0, average: 58.42
# episode: 7/300, score: 61, e: 1.0, average: 58.75
# episode: 8/300, score: 51, e: 1.0, average: 57.88
# episode: 9/300, score: 148, e: 1.0, average: 66.9
# episode: 10/300, score: 46, e: 1.0, average: 65.0
# episode: 11/300, score: 52, e: 1.0, average: 63.91
# episode: 12/300, score: 52, e: 1.0, average: 63.0
# episode: 13/300, score: 53, e: 1.0, average: 62.28
# episode: 14/300, score: 38, e: 1.0, average: 60.66
# episode: 15/300, score: 62, e: 1.0, average: 60.75
# episode: 16/300, score: 50, e: 0.98, average: 60.11
# episode: 17/300, score: 58, e: 0.92, average: 60.0
# episode: 18/300, score: 53, e: 0.88, average: 59.63
# episode: 19/300, score: 39, e: 0.84, average: 58.6
# episode: 20/300, score: 48, e: 0.8, average: 58.09
# episode: 21/300, score: 58, e: 0.76, average: 58.09
# episode: 22/300, score: 38, e: 0.73, average: 57.21
# episode: 23/300, score: 42, e: 0.7, average: 56.58
# episode: 24/300, score: 49, e: 0.67, average: 56.28
# episode: 25/300, score: 60, e: 0.63, average: 56.42
# episode: 26/300, score: 68, e: 0.59, average: 56.85
# episode: 27/300, score: 76, e: 0.54, average: 57.53
# episode: 28/300, score: 42, e: 0.52, average: 57.0
# episode: 29/300, score: 49, e: 0.5, average: 56.73
# episode: 30/300, score: 43, e: 0.47, average: 56.29
# episode: 31/300, score: 45, e: 0.45, average: 55.93
# episode: 32/300, score: 52, e: 0.43, average: 55.81
# episode: 33/300, score: 51, e: 0.41, average: 55.67
# episode: 34/300, score: 64, e: 0.38, average: 55.91
# episode: 35/300, score: 49, e: 0.37, average: 55.72
# episode: 36/300, score: 41, e: 0.35, average: 55.32
# episode: 37/300, score: 63, e: 0.33, average: 55.52
# episode: 38/300, score: 38, e: 0.32, average: 55.07
# episode: 39/300, score: 55, e: 0.3, average: 55.07
# episode: 40/300, score: 45, e: 0.29, average: 54.82
# episode: 41/300, score: 39, e: 0.28, average: 54.45
# episode: 42/300, score: 60, e: 0.26, average: 54.58
# episode: 43/300, score: 40, e: 0.25, average: 54.25
# episode: 44/300, score: 76, e: 0.23, average: 54.73
# episode: 45/300, score: 51, e: 0.22, average: 54.65
# episode: 46/300, score: 61, e: 0.21, average: 54.78
# episode: 47/300, score: 41, e: 0.2, average: 54.5
# episode: 48/300, score: 44, e: 0.19, average: 54.28
# episode: 49/300, score: 49, e: 0.18, average: 54.18
# episode: 50/300, score: 45, e: 0.17, average: 54.0
# episode: 51/300, score: 37, e: 0.17, average: 53.67
# episode: 52/300, score: 42, e: 0.16, average: 53.45
# episode: 53/300, score: 43, e: 0.15, average: 53.25
# episode: 54/300, score: 51, e: 0.15, average: 53.21
# episode: 55/300, score: 42, e: 0.14, average: 53.01
# episode: 56/300, score: 36, e: 0.13, average: 52.71
# episode: 57/300, score: 42, e: 0.13, average: 52.53
# episode: 58/300, score: 62, e: 0.12, average: 52.69
# episode: 59/300, score: 42, e: 0.12, average: 52.51
# episode: 60/300, score: 46, e: 0.11, average: 52.40
# episode: 61/300, score: 44, e: 0.11, average: 52.27
# episode: 62/300, score: 41, e: 0.1, average: 52.09
# episode: 63/300, score: 43, e: 0.098, average: 51.95
# episode: 64/300, score: 39, e: 0.094, average: 51.75
# episode: 65/300, score: 40, e: 0.09, average: 51.57
# episode: 66/300, score: 38, e: 0.087, average: 51.37
# episode: 67/300, score: 44, e: 0.083, average: 51.26
# episode: 68/300, score: 38, e: 0.08, average: 51.07
# episode: 69/300, score: 40, e: 0.077, average: 50.91
# episode: 70/300, score: 49, e: 0.073, average: 50.88
# episode: 71/300, score: 45, e: 0.07, average: 50.80
# episode: 72/300, score: 35, e: 0.068, average: 50.58
# episode: 73/300, score: 35, e: 0.065, average: 50.37
# episode: 74/300, score: 38, e: 0.063, average: 50.21
# episode: 75/300, score: 38, e: 0.06, average: 50.05
# episode: 76/300, score: 36, e: 0.058, average: 49.87
# episode: 77/300, score: 35, e: 0.056, average: 49.67
# episode: 78/300, score: 36, e: 0.054, average: 49.50
# episode: 79/300, score: 43, e: 0.052, average: 49.42
# episode: 80/300, score: 38, e: 0.05, average: 49.28
# episode: 81/300, score: 37, e: 0.048, average: 49.13
# episode: 82/300, score: 41, e: 0.046, average: 49.03
# episode: 83/300, score: 36, e: 0.045, average: 48.88
# episode: 84/300, score: 37, e: 0.043, average: 48.74
# episode: 85/300, score: 36, e: 0.042, average: 48.59
# episode: 86/300, score: 38, e: 0.04, average: 48.47
# episode: 87/300, score: 37, e: 0.039, average: 48.34
# episode: 88/300, score: 40, e: 0.037, average: 48.24
# episode: 89/300, score: 37, e: 0.036, average: 48.12
# episode: 90/300, score: 36, e: 0.034, average: 47.98
# episode: 91/300, score: 40, e: 0.033, average: 47.90
# episode: 92/300, score: 42, e: 0.032, average: 47.83
# episode: 93/300, score: 37, e: 0.031, average: 47.72
# episode: 94/300, score: 42, e: 0.029, average: 47.66
# episode: 95/300, score: 39, e: 0.028, average: 47.57
# episode: 96/300, score: 39, e: 0.027, average: 47.48
# episode: 97/300, score: 40, e: 0.026, average: 47.40
# episode: 98/300, score: 35, e: 0.025, average: 47.28
# episode: 99/300, score: 40, e: 0.024, average: 47.21
# episode: 100/300, score: 43, e: 0.023, average: 47.16
# episode: 101/300, score: 51, e: 0.022, average: 47.20
# episode: 102/300, score: 35, e: 0.021, average: 47.08
# episode: 103/300, score: 45, e: 0.02, average: 47.06
# episode: 104/300, score: 40, e: 0.02, average: 47.0
# episode: 105/300, score: 40, e: 0.019, average: 46.93
# episode: 106/300, score: 64, e: 0.018, average: 47.09
# episode: 107/300, score: 35, e: 0.017, average: 46.98
# episode: 108/300, score: 44, e: 0.016, average: 46.95
# episode: 109/300, score: 95, e: 0.015, average: 47.39
# episode: 110/300, score: 40, e: 0.014, average: 47.32
# episode: 111/300, score: 39, e: 0.014, average: 47.25
# episode: 112/300, score: 61, e: 0.013, average: 47.37
# episode: 113/300, score: 93, e: 0.012, average: 47.77
# episode: 114/300, score: 36, e: 0.011, average: 47.66
# episode: 115/300, score: 41, e: 0.011, average: 47.61
# episode: 116/300, score: 35, e: 0.01, average: 47.50
# episode: 117/300, score: 40, e: 0.01, average: 47.44
# episode: 118/300, score: 51, e: 0.0095, average: 47.47
# episode: 119/300, score: 55, e: 0.009, average: 47.53
# episode: 120/300, score: 55, e: 0.0086, average: 47.59
# episode: 121/300, score: 56, e: 0.0081, average: 47.66
# episode: 122/300, score: 37, e: 0.0078, average: 47.57
# episode: 123/300, score: 43, e: 0.0075, average: 47.54
# episode: 124/300, score: 72, e: 0.0069, average: 47.73
# episode: 125/300, score: 45, e: 0.0066, average: 47.71
# episode: 126/300, score: 214, e: 0.0054, average: 49.02
# episode: 127/300, score: 40, e: 0.0052, average: 48.95
# episode: 128/300, score: 38, e: 0.005, average: 48.86
# episode: 129/300, score: 46, e: 0.0047, average: 48.84
# episode: 130/300, score: 86, e: 0.0043, average: 49.12
# episode: 131/300, score: 46, e: 0.0041, average: 49.10
# episode: 132/300, score: 61, e: 0.0039, average: 49.19
# episode: 133/300, score: 39, e: 0.0038, average: 49.11
# episode: 134/300, score: 48, e: 0.0036, average: 49.11
# episode: 135/300, score: 52, e: 0.0034, average: 49.13
# episode: 136/300, score: 40, e: 0.0033, average: 49.06
# episode: 137/300, score: 54, e: 0.0031, average: 49.10
# episode: 138/300, score: 46, e: 0.003, average: 49.07
# episode: 139/300, score: 240, e: 0.0023, average: 50.44
# episode: 140/300, score: 38, e: 0.0022, average: 50.35
# episode: 141/300, score: 35, e: 0.0022, average: 50.24
# episode: 142/300, score: 49, e: 0.0021, average: 50.23
# episode: 143/300, score: 48, e: 0.002, average: 50.22
# episode: 144/300, score: 47, e: 0.0019, average: 50.2
# episode: 145/300, score: 40, e: 0.0018, average: 50.13
# episode: 146/300, score: 117, e: 0.0016, average: 50.58
# episode: 147/300, score: 46, e: 0.0015, average: 50.55
# episode: 148/300, score: 101, e: 0.0014, average: 50.89
# episode: 149/300, score: 111, e: 0.0012, average: 51.29
# episode: 150/300, score: 52, e: 0.0012, average: 51.29
# episode: 151/300, score: 104, e: 0.0011, average: 51.64
# episode: 152/300, score: 40, e: 0.001, average: 51.56
# episode: 153/300, score: 36, e: 0.001, average: 51.46
# episode: 154/300, score: 130, e: 0.001, average: 51.97
# episode: 155/300, score: 110, e: 0.001, average: 52.34
# episode: 156/300, score: 56, e: 0.001, average: 52.36
# episode: 157/300, score: 99, e: 0.001, average: 52.66
# episode: 158/300, score: 240, e: 0.001, average: 53.84
# episode: 159/300, score: 48, e: 0.001, average: 53.80
# episode: 160/300, score: 115, e: 0.001, average: 54.18
# episode: 161/300, score: 44, e: 0.001, average: 54.12
# episode: 162/300, score: 43, e: 0.001, average: 54.05
# episode: 163/300, score: 53, e: 0.001, average: 54.04
# episode: 164/300, score: 159, e: 0.001, average: 54.68
# episode: 165/300, score: 36, e: 0.001, average: 54.57
# episode: 166/300, score: 42, e: 0.001, average: 54.49
# episode: 167/300, score: 37, e: 0.001, average: 54.39
# episode: 168/300, score: 38, e: 0.001, average: 54.29
# episode: 169/300, score: 46, e: 0.001, average: 54.24
# episode: 170/300, score: 41, e: 0.001, average: 54.16
# episode: 171/300, score: 36, e: 0.001, average: 54.06
# episode: 172/300, score: 87, e: 0.001, average: 54.25
# episode: 173/300, score: 61, e: 0.001, average: 54.29
# episode: 174/300, score: 95, e: 0.001, average: 54.52
# episode: 175/300, score: 60, e: 0.001, average: 54.55
# episode: 176/300, score: 75, e: 0.001, average: 54.67
# episode: 177/300, score: 47, e: 0.001, average: 54.62
# episode: 178/300, score: 59, e: 0.001, average: 54.65
# episode: 179/300, score: 103, e: 0.001, average: 54.92
# episode: 180/300, score: 78, e: 0.001, average: 55.04
# episode: 181/300, score: 56, e: 0.001, average: 55.05
# episode: 182/300, score: 38, e: 0.001, average: 54.96
# episode: 183/300, score: 60, e: 0.001, average: 54.98
# episode: 184/300, score: 34, e: 0.001, average: 54.87
# episode: 185/300, score: 37, e: 0.001, average: 54.77
# episode: 186/300, score: 58, e: 0.001, average: 54.79
# episode: 187/300, score: 38, e: 0.001, average: 54.70
# episode: 188/300, score: 34, e: 0.001, average: 54.59
# episode: 189/300, score: 52, e: 0.001, average: 54.58
# episode: 190/300, score: 45, e: 0.001, average: 54.53
# episode: 191/300, score: 67, e: 0.001, average: 54.59
# episode: 192/300, score: 47, e: 0.001, average: 54.55
# episode: 193/300, score: 49, e: 0.001, average: 54.53
# episode: 194/300, score: 111, e: 0.001, average: 54.82
# episode: 195/300, score: 50, e: 0.001, average: 54.79
# episode: 196/300, score: 36, e: 0.001, average: 54.70
# episode: 197/300, score: 43, e: 0.001, average: 54.64
# episode: 198/300, score: 48, e: 0.001, average: 54.60
# episode: 199/300, score: 40, e: 0.001, average: 54.53
# episode: 200/300, score: 61, e: 0.001, average: 54.56
# episode: 201/300, score: 43, e: 0.001, average: 54.50
# episode: 202/300, score: 38, e: 0.001, average: 54.42
# episode: 203/300, score: 86, e: 0.001, average: 54.58
# episode: 204/300, score: 37, e: 0.001, average: 54.49
# episode: 205/300, score: 69, e: 0.001, average: 54.56
# episode: 206/300, score: 89, e: 0.001, average: 54.73
# episode: 207/300, score: 34, e: 0.001, average: 54.63
# episode: 208/300, score: 37, e: 0.001, average: 54.55
# episode: 209/300, score: 39, e: 0.001, average: 54.47
# episode: 210/300, score: 37, e: 0.001, average: 54.39
# episode: 211/300, score: 74, e: 0.001, average: 54.48
# episode: 212/300, score: 39, e: 0.001, average: 54.41
# episode: 213/300, score: 36, e: 0.001, average: 54.32
# episode: 214/300, score: 92, e: 0.001, average: 54.50
# episode: 215/300, score: 36, e: 0.001, average: 54.41
# episode: 216/300, score: 55, e: 0.001, average: 54.41
# episode: 217/300, score: 198, e: 0.001, average: 55.07
# episode: 218/300, score: 37, e: 0.001, average: 54.99
# episode: 219/300, score: 40, e: 0.001, average: 54.92
# episode: 220/300, score: 41, e: 0.001, average: 54.86
# episode: 221/300, score: 44, e: 0.001, average: 54.81
# episode: 222/300, score: 36, e: 0.001, average: 54.73
# episode: 223/300, score: 45, e: 0.001, average: 54.68
# episode: 224/300, score: 41, e: 0.001, average: 54.62
# episode: 225/300, score: 41, e: 0.001, average: 54.56
# episode: 226/300, score: 177, e: 0.001, average: 55.10
# episode: 227/300, score: 34, e: 0.001, average: 55.01
# episode: 228/300, score: 71, e: 0.001, average: 55.08
# episode: 229/300, score: 36, e: 0.001, average: 55.0
# episode: 230/300, score: 38, e: 0.001, average: 54.92
# episode: 231/300, score: 80, e: 0.001, average: 55.03
# episode: 232/300, score: 37, e: 0.001, average: 54.95
# episode: 233/300, score: 50, e: 0.001, average: 54.93
# episode: 234/300, score: 60, e: 0.001, average: 54.95
# episode: 235/300, score: 48, e: 0.001, average: 54.92
# episode: 236/300, score: 41, e: 0.001, average: 54.86
# episode: 237/300, score: 57, e: 0.001, average: 54.87
# episode: 238/300, score: 40, e: 0.001, average: 54.81
# episode: 239/300, score: 40, e: 0.001, average: 54.75
# episode: 240/300, score: 39, e: 0.001, average: 54.68
# episode: 241/300, score: 104, e: 0.001, average: 54.89
# episode: 242/300, score: 39, e: 0.001, average: 54.82
# episode: 243/300, score: 38, e: 0.001, average: 54.75
# episode: 244/300, score: 167, e: 0.001, average: 55.21
# episode: 245/300, score: 54, e: 0.001, average: 55.21
# episode: 246/300, score: 42, e: 0.001, average: 55.15
# episode: 247/300, score: 56, e: 0.001, average: 55.16
# episode: 248/300, score: 39, e: 0.001, average: 55.09
# episode: 249/300, score: 42, e: 0.001, average: 55.04
# episode: 250/300, score: 54, e: 0.001, average: 55.03
# episode: 251/300, score: 67, e: 0.001, average: 55.08
# episode: 252/300, score: 43, e: 0.001, average: 55.03
# episode: 253/300, score: 58, e: 0.001, average: 55.05
# episode: 254/300, score: 45, e: 0.001, average: 55.01
# episode: 255/300, score: 59, e: 0.001, average: 55.02
# episode: 256/300, score: 42, e: 0.001, average: 54.97
# episode: 257/300, score: 50, e: 0.001, average: 54.95
# episode: 258/300, score: 41, e: 0.001, average: 54.90
# episode: 259/300, score: 38, e: 0.001, average: 54.83
# episode: 260/300, score: 35, e: 0.001, average: 54.76
# episode: 261/300, score: 43, e: 0.001, average: 54.71
# episode: 262/300, score: 240, e: 0.001, average: 55.42
# episode: 263/300, score: 96, e: 0.001, average: 55.57
# episode: 264/300, score: 40, e: 0.001, average: 55.51
# episode: 265/300, score: 43, e: 0.001, average: 55.46
# episode: 266/300, score: 127, e: 0.001, average: 55.73
# episode: 267/300, score: 49, e: 0.001, average: 55.71
# episode: 268/300, score: 71, e: 0.001, average: 55.76
# episode: 269/300, score: 45, e: 0.001, average: 55.72
# episode: 270/300, score: 41, e: 0.001, average: 55.67
# episode: 271/300, score: 75, e: 0.001, average: 55.74
# episode: 272/300, score: 95, e: 0.001, average: 55.89
# episode: 273/300, score: 40, e: 0.001, average: 55.83
# episode: 274/300, score: 56, e: 0.001, average: 55.83
# episode: 275/300, score: 49, e: 0.001, average: 55.80
# episode: 276/300, score: 46, e: 0.001, average: 55.77
# episode: 277/300, score: 40, e: 0.001, average: 55.71
# episode: 278/300, score: 63, e: 0.001, average: 55.74
# episode: 279/300, score: 47, e: 0.001, average: 55.71
# episode: 280/300, score: 39, e: 0.001, average: 55.65
# episode: 281/300, score: 40, e: 0.001, average: 55.59
# episode: 282/300, score: 82, e: 0.001, average: 55.68
# episode: 283/300, score: 68, e: 0.001, average: 55.73
# episode: 284/300, score: 44, e: 0.001, average: 55.69
# episode: 285/300, score: 38, e: 0.001, average: 55.62
# episode: 286/300, score: 44, e: 0.001, average: 55.58
# episode: 287/300, score: 50, e: 0.001, average: 55.56
# episode: 288/300, score: 47, e: 0.001, average: 55.53
# episode: 289/300, score: 83, e: 0.001, average: 55.63
# episode: 290/300, score: 43, e: 0.001, average: 55.59
# episode: 291/300, score: 54, e: 0.001, average: 55.58
# episode: 292/300, score: 59, e: 0.001, average: 55.59
# episode: 293/300, score: 37, e: 0.001, average: 55.53
# episode: 294/300, score: 90, e: 0.001, average: 55.65
# episode: 295/300, score: 40, e: 0.001, average: 55.59
# episode: 296/300, score: 43, e: 0.001, average: 55.55
# episode: 297/300, score: 44, e: 0.001, average: 55.51
# episode: 298/300, score: 44, e: 0.001, average: 55.47
# episode: 299/300, score: 115, e: 0.001, average: 55.67

# %%
agent.test("/home/cbeario/DeepPrior/drone-dqn.pt")
